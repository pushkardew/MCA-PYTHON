# %%
# Number System Converter

num_str = input("Enter a number: ")
print("Number is", num_str)
# Out:
# Number is 25

# %%
num = int(num_str) # user se number lo

print("Binary:", bin(num)[2:])    
print("Octal:", oct(num)[2:])      
print("Hexadecimal:", hex(num)[2:].upper())
# Out:
# Binary: 11001
# Octal: 31
# Hexadecimal: 19
