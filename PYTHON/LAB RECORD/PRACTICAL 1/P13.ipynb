# %%
length = 12

print("Password length:", length)
# Out:
# Password length: 12

# %%
import random
import string

uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase
digits = string.digits
symbols = "!@#$*"

try:
    # First character must be Capital letter or Digit
    first_char = random.choice(uppercase + digits)

    # Remaining characters
    all_chars = uppercase + lowercase + digits + symbols
    remaining_chars = random.choices(all_chars, k=length - 1)

    password = first_char + "".join(remaining_chars)

    print("Generated Password:", password)

except Exception as e:
    print("Error:", e)
# Out:
# Generated Password: X90pq*Jg70fC
