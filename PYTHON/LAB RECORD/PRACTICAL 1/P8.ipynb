# %%
# Dislay Studdent with highest marks

student_marks = [('Leeladhar', 88), ('Aman', 92), ('lokesh', 79)]
print("Student Marks:", student_marks)
# Out:
# Student Marks: [('Leeladhar', 88), ('Aman', 92), ('lokesh', 79)]

# %%
topper = max(student_marks, key=lambda item: item[1])

print(f"Topper: {topper[0]} ({topper[1]})")
# Out:
# Topper: Aman (92)
