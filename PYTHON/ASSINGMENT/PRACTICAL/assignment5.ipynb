# %%
employees = [
    {"name": 'Ram', "salary": 45000},
    {"name": 'Shyam', "salary": 52000},
    {"name": 'Radha', "salary": 48000},
    {"name": 'Shiv', "salary": 60000}
]

sorted_employees = sorted(employees, key=lambda x: x['salary'])
print("Sorted by Salary:\n", sorted_employees)
# Out:
# Sorted by Salary:
#  [{'name': 'Ram', 'salary': 45000}, {'name': 'Radha', 'salary': 48000}, {'name': 'Shyam', 'salary': 52000}, {'name': 'Shiv', 'salary': 60000}]
