# %%
def probability(favorable_outcomes, total_outcomes):
    return favorable_outcomes / total_outcomes

def probability_of_die_roll():
    total_outcomes = 6  
    favorable_outcomes = 1
    prob = probability(favorable_outcomes, total_outcomes)
    print("Probability of rolling a specific number on a die:", prob)

def probability_of_coin_flip():
    total_outcomes = 2  
    favorable_outcomes = 1 
    prob = probability(favorable_outcomes, total_outcomes)
    print("Probability of getting Heads:", prob)

probability_of_die_roll()
probability_of_coin_flip()
# Out:
# Probability of rolling a specific number on a die: 0.16666666666666666
# Probability of getting Heads: 0.5
