# %%
files = ['report.pdf', 'data.csv', 'photo.jpg', 'summary.pdf', 'script.py']
file_dict = {}

for file in files:
    ext = file.split('.')[-1]
    file_dict.setdefault(ext, []).append(file)

print(file_dict)
